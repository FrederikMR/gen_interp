# %% [markdown]
# # Torch Example for Interpolation

# %%
import torch

import matplotlib.pyplot as plt

from torch_geometry.manifolds import nSphere
from torch_geometry.prob_geodesics import ProbGEORCE, ProbGEORCE_Embedded, ProbGEORCE_Euclidean

# %% [markdown]
# ## Defining manifold and funcitons

# %% [markdown]
# ### Define manifold

# %%
#Simple Euclidean example
M = nSphere(dim=2)
z0 = -torch.ones(2, dtype=torch.float32)
zN = torch.ones(2, dtype=torch.float32)

# %% [markdown]
# ### Regularization function

# %%
#error to a unit circle
def reg_fun(x):

    return torch.sum((torch.sum(x**2, axis=-1)-1.0)**2)

# %% [markdown]
# ### Projection function

# %%
#dummy projection function
def proj_fun(x):

    return x

# %% [markdown]
# ## Computing geodesics

# %% [markdown]
# ### ProbGEORCE

# %%
ProbGeodesic = ProbGEORCE(M=M,
                          reg_fun=reg_fun,
                          init_fun=None,
                          lam=1.0,
                          N=100,
                          tol=1e-4,
                          max_iter=1000,
                          line_search_params = {'rho': 0.5},
                          device='cpu',
                         )

# %%
curve = ProbGeodesic(z0,zN)

# %%
plt.plot(curve[:,0], curve[:,1])

# %% [markdown]
# ### ProbGEORCE Euclidean

# %%
ProbGeodesic = ProbGEORCE_Euclidean(reg_fun=reg_fun,
                                    init_fun=None,
                                    lam=1.0,
                                    N=100,
                                    tol=1e-4,
                                    max_iter=1000,
                                    line_search_params = {'rho': 0.5},
                                    device='cpu',
                                   )

# %%
curve = ProbGeodesic(z0,zN)

# %%
plt.plot(curve[:,0], curve[:,1])

# %% [markdown]
# ### ProbGEORCE Embedded

# %%
def metric_matrix(x):

    if x.ndim == 1:
        return M.G(x)
    else:
        return torch.vmap(M.G)(x)

ProbGeodesic = ProbGEORCE_Embedded(metric_matrix=metric_matrix,
                                   reg_fun=reg_fun,
                                   proj_fun=proj_fun,
                                   init_fun=None,
                                   lam1=1.0,
                                   lam2=1.0,
                                   N=100,
                                   tol=1e-4,
                                   max_iter=1000,
                                   line_search_params = {'rho': 0.5},
                                   device='cpu',
                                  )

# %%
curve = ProbGeodesic(z0,zN)
# Out:
# tensor(4.2071)

# %%
plt.plot(curve[:,0], curve[:,1])
